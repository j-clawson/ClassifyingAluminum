# %% [markdown]
# ## Loading Required Libraries/Packages

# %%
import lightgbm as lgb
from catboost import CatBoostClassifier, Pool
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss

# %% [markdown]
# ## Preprocessing

# %%
# Loading our datasets

train_df = pd.read_csv("aluminum_coldRoll_train.csv")
test_df = pd.read_csv("aluminum_coldRoll_testNoY.csv")

# Separating target data from test data

y = train_df["y_passXtremeDurability"]
X = train_df.drop(columns = ["y_passXtremeDurability", "ID"])
test_ids = test_df["ID"]
X_test = test_df.drop(columns = "ID")

# Converting to category data type for LightGBM (one of two boosting models utilized)

cat_cols = X.select_dtypes(include = "object").columns.tolist()
for col in cat_cols:
    X[col] = X[col].astype('category')
    X_test[col] = X_test[col].astype('category')

# %% [markdown]
# ## LightGBM Preprocessing

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 35, stratify = y)

# Creating our LightGBM train and validation datasets
lgb_train = lgb.Dataset(X_train, label = y_train, categorical_feature = cat_cols)
lgb_val = lgb.Dataset(X_val, label = y_val, categorical_feature = cat_cols)

# %% [markdown]
# ### Defining LightGBM Hyperparameters

# %%
params_lgb = {
    "objective": "binary",
    "metric": "binary_logloss",
    "learning_rate": 0.05,
    "num_leaves": 5,
    "feature_fraction": 0.8,
    "bagging_fraction": 0.8,
    "bagging_freq": 1,
    "min_data_in_leaf": 125,
    "lambda_l2": 1.2,
    "seed": 42,
    "verbose": -1
}

# %% [markdown]
# ### Training Our Model

# %%
lgb_model = lgb.train(
    params_lgb,
    lgb_train,
    num_boost_round = 5000,
    valid_sets = lgb_val,
    valid_names = "val",
    callbacks = [
        lgb.early_stopping(stopping_rounds = 100),
        lgb.log_evaluation(period = 100)
    ]
)

val_predictions = lgb_model.predict(X_val, num_iteration = lgb_model.best_iteration)
print("LightGBM Validation Set Logloss:", log_loss(y_val, val_predictions))
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	val's binary_logloss: 0.484646
# [200]	val's binary_logloss: 0.451004
# [300]	val's binary_logloss: 0.438361
# [400]	val's binary_logloss: 0.432899
# [500]	val's binary_logloss: 0.430429
# [600]	val's binary_logloss: 0.429258
# [700]	val's binary_logloss: 0.4287
# [800]	val's binary_logloss: 0.428536
# [900]	val's binary_logloss: 0.428356
# [1000]	val's binary_logloss: 0.428282
# [1100]	val's binary_logloss: 0.428232
# Early stopping, best iteration is:
# [1082]	val's binary_logloss: 0.428227
# LightGBM Validation Set Logloss: 0.4282273429164156

# %% [markdown]
# ### Fitting Our LightGBM Model

# %% [markdown]
# Now that we have obtained a validation set logloss for one particular seed (42), let's average our predictions across multiple seeds in an attempt to reduce variance.

# %%
best_iteration = lgb_model.best_iteration

seeds = [0, 1, 2, 3, 4, 5, 6, 7]
lgb_test_predictions = []

for s in seeds:
    params_lgb_copy = params_lgb.copy()
    params_lgb_copy["seed"] = s

    print(f"Training LGB Model with seed {s}")
    lgb_full_model = lgb.train(
        params_lgb_copy,
    lgb.Dataset(X, label = y, categorical_feature = cat_cols),
    num_boost_round = best_iteration
    )

    lgb_test_predictions.append(lgb_full_model.predict(X_test, num_iteration = best_iteration))

lgb_seed_ensemble_predictions = np.mean(lgb_test_predictions, axis = 0)
# Out:
# Training LGB Model with seed 0
# Training LGB Model with seed 1
# Training LGB Model with seed 2
# Training LGB Model with seed 3
# Training LGB Model with seed 4
# Training LGB Model with seed 5
# Training LGB Model with seed 6
# Training LGB Model with seed 7

# %% [markdown]
# ## Defining Hyperparameters for CatBoost

# %%
params_cat = {
    "depth": 4,
    "learning_rate": 0.05,
    "iterations": 1150,
    "l2_leaf_reg": 4,
    "random_strength": 5,
    "loss_function": "Logloss",
    "eval_metric": "Logloss",
    "random_seed": 42,
    "verbose": 100
}

# %% [markdown]
# ### Fitting Our CatBoost Model

# %%
seeds = [0, 1, 2, 3, 4, 5, 6, 7]

cat_test_preds = []

for s in seeds:
    print(f"Training CatBoost with seed {s}")
    cat_params_copy = params_cat.copy()
    cat_params_copy["random_seed"] = s

    train_pool = Pool(X, y, cat_features = cat_cols)
    test_pool  = Pool(X_test, cat_features = cat_cols)
    
    cat_model = CatBoostClassifier(**cat_params_copy)
    cat_model.fit(train_pool)      
    
    cat_probabilities = cat_model.predict_proba(test_pool)[:, 1]
    cat_test_preds.append(cat_probabilities)
# Out:
# Training CatBoost with seed 0
# 0:	learn: 0.6745550	total: 398ms	remaining: 7m 37s
# 100:	learn: 0.4596262	total: 18.4s	remaining: 3m 11s
# 200:	learn: 0.4402235	total: 34.9s	remaining: 2m 44s
# 300:	learn: 0.4297828	total: 52.7s	remaining: 2m 28s
# 400:	learn: 0.4255617	total: 1m 11s	remaining: 2m 13s
# 500:	learn: 0.4237595	total: 1m 29s	remaining: 1m 55s
# 600:	learn: 0.4229638	total: 1m 46s	remaining: 1m 36s
# 700:	learn: 0.4223474	total: 2m 4s	remaining: 1m 19s
# 800:	learn: 0.4218932	total: 2m 26s	remaining: 1m 3s
# 900:	learn: 0.4215605	total: 2m 47s	remaining: 46.4s
# 1000:	learn: 0.4212723	total: 3m 9s	remaining: 28.1s
# 1100:	learn: 0.4209971	total: 3m 29s	remaining: 9.34s
# 1149:	learn: 0.4208827	total: 3m 39s	remaining: 0us
# Training CatBoost with seed 1
# 0:	learn: 0.6764131	total: 250ms	remaining: 4m 47s
# 100:	learn: 0.4590692	total: 18.3s	remaining: 3m 10s
# 200:	learn: 0.4400427	total: 36.7s	remaining: 2m 53s
# 300:	learn: 0.4295037	total: 55.5s	remaining: 2m 36s
# 400:	learn: 0.4254775	total: 1m 15s	remaining: 2m 20s
# 500:	learn: 0.4235220	total: 1m 34s	remaining: 2m 3s
# 600:	learn: 0.4227156	total: 1m 55s	remaining: 1m 45s
# 700:	learn: 0.4221759	total: 2m 16s	remaining: 1m 27s
# 800:	learn: 0.4217402	total: 2m 37s	remaining: 1m 8s
# 900:	learn: 0.4213614	total: 2m 59s	remaining: 49.6s
# 1000:	learn: 0.4210294	total: 3m 22s	remaining: 30.1s
# 1100:	learn: 0.4207482	total: 3m 43s	remaining: 9.96s
# 1149:	learn: 0.4206426	total: 3m 53s	remaining: 0us
# Training CatBoost with seed 2
# 0:	learn: 0.6736861	total: 244ms	remaining: 4m 39s
# 100:	learn: 0.4603224	total: 18.6s	remaining: 3m 12s
# 200:	learn: 0.4405349	total: 37.2s	remaining: 2m 55s
# 300:	learn: 0.4295540	total: 57.2s	remaining: 2m 41s
# 400:	learn: 0.4253108	total: 1m 18s	remaining: 2m 26s
# 500:	learn: 0.4236273	total: 1m 39s	remaining: 2m 9s
# 600:	learn: 0.4226620	total: 2m 1s	remaining: 1m 51s
# 700:	learn: 0.4221039	total: 2m 23s	remaining: 1m 31s
# 800:	learn: 0.4217055	total: 2m 45s	remaining: 1m 12s
# 900:	learn: 0.4213401	total: 3m 7s	remaining: 51.8s
# 1000:	learn: 0.4210692	total: 3m 29s	remaining: 31.2s
# 1100:	learn: 0.4208022	total: 3m 51s	remaining: 10.3s
# 1149:	learn: 0.4206875	total: 4m 1s	remaining: 0us
# Training CatBoost with seed 3
# 0:	learn: 0.6757829	total: 246ms	remaining: 4m 42s
# 100:	learn: 0.4595750	total: 19.9s	remaining: 3m 26s
# 200:	learn: 0.4400885	total: 40s	remaining: 3m 8s
# 300:	learn: 0.4295797	total: 1m	remaining: 2m 50s
# 400:	learn: 0.4253798	total: 1m 21s	remaining: 2m 31s
# 500:	learn: 0.4236047	total: 1m 43s	remaining: 2m 13s
# 600:	learn: 0.4228040	total: 2m 3s	remaining: 1m 53s
# 700:	learn: 0.4223031	total: 2m 25s	remaining: 1m 33s
# 800:	learn: 0.4218952	total: 2m 47s	remaining: 1m 13s
# 900:	learn: 0.4215152	total: 3m 9s	remaining: 52.3s
# 1000:	learn: 0.4211966	total: 3m 31s	remaining: 31.4s
# 1100:	learn: 0.4208923	total: 3m 53s	remaining: 10.4s
# 1149:	learn: 0.4207620	total: 4m 3s	remaining: 0us
# Training CatBoost with seed 4
# 0:	learn: 0.6736810	total: 186ms	remaining: 3m 33s
# 100:	learn: 0.4595430	total: 18.3s	remaining: 3m 10s
# 200:	learn: 0.4409602	total: 36.9s	remaining: 2m 54s
# 300:	learn: 0.4300014	total: 57.4s	remaining: 2m 41s
# 400:	learn: 0.4257457	total: 1m 19s	remaining: 2m 27s
# 500:	learn: 0.4238840	total: 1m 40s	remaining: 2m 10s
# 600:	learn: 0.4230040	total: 2m 2s	remaining: 1m 52s
# 700:	learn: 0.4224140	total: 2m 24s	remaining: 1m 32s
# 800:	learn: 0.4219861	total: 2m 46s	remaining: 1m 12s
# 900:	learn: 0.4216125	total: 3m 8s	remaining: 52.1s
# 1000:	learn: 0.4213147	total: 3m 30s	remaining: 31.4s
# 1100:	learn: 0.4210344	total: 3m 52s	remaining: 10.4s
# 1149:	learn: 0.4209280	total: 4m 3s	remaining: 0us
# Training CatBoost with seed 5
# 0:	learn: 0.6756144	total: 224ms	remaining: 4m 17s
# 100:	learn: 0.4583910	total: 19.9s	remaining: 3m 26s
# 200:	learn: 0.4402734	total: 39.4s	remaining: 3m 5s
# 300:	learn: 0.4299503	total: 59.3s	remaining: 2m 47s
# 400:	learn: 0.4254228	total: 1m 19s	remaining: 2m 29s
# 500:	learn: 0.4237867	total: 1m 41s	remaining: 2m 11s
# 600:	learn: 0.4229702	total: 2m 2s	remaining: 1m 51s
# 700:	learn: 0.4223620	total: 2m 24s	remaining: 1m 32s
# 800:	learn: 0.4219099	total: 2m 46s	remaining: 1m 12s
# 900:	learn: 0.4215420	total: 3m 7s	remaining: 51.9s
# 1000:	learn: 0.4212405	total: 3m 29s	remaining: 31.2s
# 1100:	learn: 0.4209643	total: 3m 51s	remaining: 10.3s
# 1149:	learn: 0.4208366	total: 4m 2s	remaining: 0us
# Training CatBoost with seed 6
# 0:	learn: 0.6760543	total: 248ms	remaining: 4m 45s
# 100:	learn: 0.4597557	total: 19.2s	remaining: 3m 19s
# 200:	learn: 0.4400818	total: 38.5s	remaining: 3m 1s
# 300:	learn: 0.4298321	total: 59s	remaining: 2m 46s
# 400:	learn: 0.4255352	total: 1m 19s	remaining: 2m 28s
# 500:	learn: 0.4236723	total: 1m 40s	remaining: 2m 9s
# 600:	learn: 0.4227924	total: 2m 1s	remaining: 1m 50s
# 700:	learn: 0.4222457	total: 2m 22s	remaining: 1m 31s
# 800:	learn: 0.4218483	total: 2m 44s	remaining: 1m 11s
# 900:	learn: 0.4215299	total: 3m 6s	remaining: 51.6s
# 1000:	learn: 0.4212352	total: 3m 28s	remaining: 31.1s
# 1100:	learn: 0.4209694	total: 3m 50s	remaining: 10.3s
# 1149:	learn: 0.4208337	total: 4m	remaining: 0us
# Training CatBoost with seed 7
# 0:	learn: 0.6760564	total: 249ms	remaining: 4m 45s
# 100:	learn: 0.4597546	total: 19.3s	remaining: 3m 20s
# 200:	learn: 0.4391228	total: 38.2s	remaining: 3m
# 300:	learn: 0.4295146	total: 58.8s	remaining: 2m 45s
# 400:	learn: 0.4254538	total: 1m 19s	remaining: 2m 28s
# 500:	learn: 0.4235702	total: 1m 40s	remaining: 2m 10s
# 600:	learn: 0.4228897	total: 2m 2s	remaining: 1m 51s
# 700:	learn: 0.4223210	total: 2m 24s	remaining: 1m 32s
# 800:	learn: 0.4219365	total: 2m 46s	remaining: 1m 12s
# 900:	learn: 0.4216440	total: 3m 7s	remaining: 51.7s
# 1000:	learn: 0.4213151	total: 3m 29s	remaining: 31.2s
# 1100:	learn: 0.4210365	total: 3m 50s	remaining: 10.3s
# 1149:	learn: 0.4208983	total: 4m 1s	remaining: 0us

# %%
cat_seed_ensemble_predictions = np.mean(cat_test_preds, axis = 0)

# %% [markdown]
# ### Stacking our Models to Generate Final Predictions

# %%
final_probs = 0.8 * cat_seed_ensemble_predictions + (1 - 0.8) * lgb_seed_ensemble_predictions

# %%
submission = pd.DataFrame({
    "ID": test_ids,
    "y_passXtremeDurability": final_probs
})

# %%
submission.head()
# Out:
#        ID  y_passXtremeDurability
# 0  160001                0.003709
# 1  160002                0.051257
# 2  160003                0.937125
# 3  160004                0.715209
# 4  160005                0.808375

# %% [markdown]
# Example Submission: submission.to_csv("Team20_CatBoost+LightGBMAlpha080+SeedBoth_Dec1#3.csv", index=False)
